# %%
import pandas as pd

# %%
url="https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
column_names=['mpg','cylinders','displacement','horspower','weight','acceleration','model_year','origin','car_name']

df=pd.read_csv(url,delim_whitespace=True,names=column_names,na_values='?',comment='\t')
df.head()
# Out:
# C:\Users\Tanushree Gupta\AppData\Local\Temp\ipykernel_15520\2669128246.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df=pd.read_csv(url,delim_whitespace=True,names=column_names,na_values='?',comment='\t')
#     mpg  cylinders  displacement  horspower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# ...

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horspower       6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
df.horspower.describe()
# Out:
# count    392.000000
# mean     104.469388
# std       38.491160
# min       46.000000
# 25%       75.000000
# 50%       93.500000
# 75%      126.000000
# max      230.000000
# Name: horspower, dtype: float64

# %%
df.horspower.fillna(df.horspower.mean(),inplace=True)

# %%
df.horspower.describe()
# Out:
# count    398.000000
# mean     104.469388
# std       38.199187
# min       46.000000
# 25%       76.000000
# 50%       95.000000
# 75%      125.000000
# max      230.000000
# Name: horspower, dtype: float64

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horspower       0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# car_name        0
# dtype: int64

# %%
features=['cylinders','displacement','horspower','weight','acceleration','model_year','origin']
X=df[features]
Y=df['mpg']

# %%
X.head()
# Out:
#    cylinders  displacement  horspower  weight  acceleration  model_year  \
# 0          8         307.0      130.0  3504.0          12.0          70
# 1          8         350.0      165.0  3693.0          11.5          70
# 2          8         318.0      150.0  3436.0          11.0          70
# 3          8         304.0      150.0  3433.0          12.0          70
# 4          8         302.0      140.0  3449.0          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X.shape
# Out:
# (398, 7)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_test.shape
# Out:
# (80, 7)

# %%
model =LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred[:5]
# Out:
# array([32.86345735, 29.58130242, 21.35126058, 16.80568721, 12.50136229])

# %%
y_test[:5]
# Out:
# 198    33.0
# 396    28.0
# 33     19.0
# 208    13.0
# 93     14.0
# Name: mpg, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 8.19545210407378

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8475731044779435

# %%
model.score(X_test,y_test)
# Out:
# 0.8475731044779435
